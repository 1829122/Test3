# %% [markdown]
# <a href="https://colab.research.google.com/github/1829122/Test3/blob/main/APICall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

def factadressCall(stn): # 이거는 공장 위치입니다.
  url = 'http://apis.data.go.kr/B552584/cleansys/recentThYearCmprFyerBsnesStatsInfo'
  params ={'serviceKey' : 'zyPKasfClmXWQUP0jZLMGiyMTO0Ykuzu1p5AXxRMTWZLpzeDtt58hJaPT4VvUMpwsswMa2pMScIgEKCGwb3ECw==', 'areaNm' : stn, 'searchYear' : '2020', 'type' : 'json' }
  try:
    response = requests.get(url, params=params)
    data2 = response.json()
    return data2
  except json.JSONDecodeError:
    factadressCall(stn)


fact_data1 = factadressCall('울산') #울산
print(fact_data1)
# Out:
# {'response': {'header': {'resultCode': '0', 'totalCount': 93, 'resultMsg': 'NORMAL_CODE'}, 'body': {'items': [{'nox_dscamt_yy2': None, 'nox_dscamt_yy1': None, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '울산광역시 남구 용잠로 583-93', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': None, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': None, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)비아이티', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': None, 'nox_dscamt_yy1': None, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '울산광역시 남구 처용로 695', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': None, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': None, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)에너지파크', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': 5258842.0, 'nox_dscamt_yy1': 3572068.0, 'co_dscamt_yy3': 64219.0, 'co_dscamt_yy2': 60594.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 110735.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 930171.0, 'sox_dscamt_yy2': 1172474.0, 'sox_dscamt_yy3': 1424026.0, 'hcl_dscamt_yy1': None, 'fact_adres': '울산광역시 남구 신여천로 2 (고사동)', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': 84696.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 109153.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 108063.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)에스케이에너지', 'nox_dscamt_yy3': 5911245.0}, {'nox_dscamt_yy2': 57394.0, 'nox_dscamt_yy1': 35895.0, 'co_dscamt_yy3': 17284.0, 'co_dscamt_yy2': 20497.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 13801.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': 320.0, 'fact_adres': '울산광역시 남구 장생포로 285 (매암동)', 'hcl_dscamt_yy2': 864.0, 'hcl_dscamt_yy3': 721.0, 'tsp_dscamt_yy1': 285.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 270.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 219.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)에팩', 'nox_dscamt_yy3': 59011.0}, {'nox_dscamt_yy2': 24381.0, 'nox_dscamt_yy1': 14282.0, 'co_dscamt_yy3': 4425.0, 'co_dscamt_yy2': 4191.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 4697.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 6664.0, 'sox_dscamt_yy2': 4633.0, 'sox_dscamt_yy3': 4844.0, 'hcl_dscamt_yy1': 1246.0, 'fact_adres': '울산광역시 남구 용잠로 339 (용잠동)', 'hcl_dscamt_yy2': 782.0, 'hcl_dscamt_yy3': 1077.0, 'tsp_dscamt_yy1': 976.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 1244.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 1033.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': 'NC울산㈜', 'nox_dscamt_yy3': 26535.0}, {'nox_dscamt_yy2': 2258965.0, 'nox_dscamt_yy1': 1742489.0, 'co_dscamt_yy3': 9074.0, 'co_dscamt_yy2': 8557.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 9320.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 82449.0, 'sox_dscamt_yy2': 99169.0, 'sox_dscamt_yy3': 422125.0, 'hcl_dscamt_yy1': None, 'fact_adres': '울산광역시 울주군 온산읍 온산로 68', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': 4293.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 4718.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 1302.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': 'S-OIL㈜ 온산공장', 'nox_dscamt_yy3': 2939383.0}, {'nox_dscamt_yy2': 174426.0, 'nox_dscamt_yy1': 96409.0, 'co_dscamt_yy3': 10231.0, 'co_dscamt_yy2': 11289.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 10678.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '울산광역시 남구 용잠로 255', 'hcl_dsc ...

# %%
fact_data2 = factadressCall('경상북도') #경상북도
print(fact_data2)
# Out:
# {'response': {'header': {'resultCode': '0', 'totalCount': 84, 'resultMsg': 'NORMAL_CODE'}, 'body': {'items': [{'nox_dscamt_yy2': None, 'nox_dscamt_yy1': None, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '경상북도 구미시 1공단로4길 40', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': None, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': None, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)미래금속', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': None, 'nox_dscamt_yy1': None, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '경상북도 포항시 남구 대송면 철강산단로66번길 40', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': None, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': None, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)삼원강재', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': 15292.0, 'nox_dscamt_yy1': 10771.0, 'co_dscamt_yy3': 423.0, 'co_dscamt_yy2': 1386.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 2685.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 1867.0, 'sox_dscamt_yy2': 2031.0, 'sox_dscamt_yy3': 1184.0, 'hcl_dscamt_yy1': 577.0, 'fact_adres': '경상북도 경산시 진량읍 대구대로 355-26', 'hcl_dscamt_yy2': 688.0, 'hcl_dscamt_yy3': 384.0, 'tsp_dscamt_yy1': 1209.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 986.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 601.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)에코비트에너지 경산', 'nox_dscamt_yy3': 17514.0}, {'nox_dscamt_yy2': 27797.0, 'nox_dscamt_yy1': 24116.0, 'co_dscamt_yy3': None, 'co_dscamt_yy2': 11105.0, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': 7960.0, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 295.0, 'sox_dscamt_yy2': 163.0, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': 451.0, 'fact_adres': '경상북도 경주시 안강읍 두류길 218-116', 'hcl_dscamt_yy2': 71.0, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': 777.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 337.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)에코비트에너지 정세', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': None, 'nox_dscamt_yy1': None, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '경상북도 구미시 수출대로 228', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': None, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': None, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': None, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)엘에스전선', 'nox_dscamt_yy3': None}, {'nox_dscamt_yy2': 785478.0, 'nox_dscamt_yy1': 611192.0, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': 213755.0, 'sox_dscamt_yy2': 210165.0, 'sox_dscamt_yy3': 261249.0, 'hcl_dscamt_yy1': None, 'fact_adres': '경상북도 구미시 1공단로6길 54', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dscamt_yy1': 8228.0, 'nh3_dscamt_yy1': None, 'tsp_dscamt_yy2': 9116.0, 'nh3_dscamt_yy2': None, 'tsp_dscamt_yy3': 14569.0, 'nh3_dscamt_yy3': None, 'fact_manage_nm': '(주)지에스구미열병합발전', 'nox_dscamt_yy3': 932323.0}, {'nox_dscamt_yy2': 483719.0, 'nox_dscamt_yy1': 419993.0, 'co_dscamt_yy3': None, 'co_dscamt_yy2': None, 'hf_dscamt_yy3': None, 'co_dscamt_yy1': None, 'hf_dscamt_yy2': None, 'hf_dscamt_yy1': None, 'sox_dscamt_yy1': None, 'sox_dscamt_yy2': None, 'sox_dscamt_yy3': None, 'hcl_dscamt_yy1': None, 'fact_adres': '경상북도 포항시 남구 동해안로 6262', 'hcl_dscamt_yy2': None, 'hcl_dscamt_yy3': None, 'tsp_dsc ...

# %%
Ulsan_data = [
    {
        "fact_manage_nm": item["fact_manage_nm"],
        "address" : item["fact_adres"]
    } for item in fact_data1["response"]["body"]["items"]
]

Pohang_data = [
    {
        "fact_manage_nm": item["fact_manage_nm"],
        "address" : item["fact_adres"]
    } for item in fact_data2["response"]["body"]["items"] if '포항' in item["fact_adres"]
]


base_data = {
    "울산광역시": Ulsan_data,
    "포항시" : Pohang_data
}


with open('base_data.json', "w", encoding='utf-8') as json_file:
    json.dump(base_data, json_file, ensure_ascii=False)

base_data
# Out:
# {'울산광역시': [{'fact_manage_nm': '(주)비아이티', 'address': '울산광역시 남구 용잠로 583-93'},
#   {'fact_manage_nm': '(주)에너지파크', 'address': '울산광역시 남구 처용로 695'},
#   {'fact_manage_nm': '(주)에스케이에너지', 'address': '울산광역시 남구 신여천로 2 (고사동)'},
#   {'fact_manage_nm': '(주)에팩', 'address': '울산광역시 남구 장생포로 285 (매암동)'},
#   {'fact_manage_nm': 'NC울산㈜', 'address': '울산광역시 남구 용잠로 339 (용잠동)'},
#   {'fact_manage_nm': 'S-OIL㈜ 온산공장', 'address': '울산광역시 울주군 온산읍 온산로 68'},
#   {'fact_manage_nm': 'SK picglobal㈜', 'address': '울산광역시 남구 용잠로 255'},
#   {'fact_manage_nm': 'SK가스㈜', 'address': '울산광역시 남구 용잠로 566'},
#   {'fact_manage_nm': 'SK엔무브㈜', 'address': '울산광역시 남구 신여천로 2'},
#   {'fact_manage_nm': 'SK지오센트릭(주)', 'address': '울산광역시 남구 신여천로 2'},
#   {'fact_manage_nm': '㈜동남 울산공장', 'address': '울산광역시 울주군 온산읍 석당길 29'},
#   {'fact_manage_nm': '㈜동부에너지', 'address': '울산광역시 남구 장생포로 285 (매암동)'},
#   {'fact_manage_nm': '㈜범우', 'address': '울산광역시 울주군 온산읍 온산로 219-3'},
#   {'fact_manage_nm': '㈜삼양사 울산1공장', 'address': '울산광역시 남구 장생포로 285'},
#   {'fact_manage_nm': '㈜삼양사 울산2공장', 'address': '울산광역시 남구 매암로 115'},
#   {'fact_manage_nm': '㈜세진메탈', 'address': '울산광역시 울주군 온산읍 원봉로 15'},
#   {'fact_manage_nm': '㈜세진메탈 3공장', 'address': '울산광역시 울주군 온산읍 석당길 29-13'},
#   {'fact_manage_nm': '㈜에코비트에너지 울산', 'address': '울산광역시 남구 여천로 228 (여천동)'},
#   {'fact_manage_nm': '㈜엘엑스하우시스', 'address': '울산광역시 울주군 온양읍 덕망로 275'},
#   {'fact_manage_nm': '㈜우신금속', 'address': '울산광역시 울주군 온산읍 처용산업2길 17'},
#   {'fact_manage_nm': '㈜유니큰 온산공장', 'address': '울산광역시 울주군 온산읍 원산로 59'},
#   {'fact_manage_nm': '㈜이수화학 온산공장', 'address': '울산광역시 울주군 온산읍 석당길 8'},
#   {'fact_manage_nm': '㈜이수화학 울산공장', 'address': '울산광역시 남구 사평로 108-224'},
#   {'fact_manage_nm': '㈜제이엠씨', 'address': '울산광역시 울주군 온산읍 이진로 71'},
#   {'fact_manage_nm': '㈜조비', 'address': '울산광역시 남구 여천로163번길 22 (여천동)'},
#   {'fact_manage_nm': '㈜카프로', 'address': '울산광역시 남구 사평로 108-12 (부곡동)'},
#   {'fact_manage_nm': '㈜코엔텍', 'address': '울산광역시 남구 용잠로 328 (용잠동)'},
#   {'fact_manage_nm': '㈜토탈', 'address': '울산광역시 남구 용연로179번길 18 (용연동)'},
#   {'fact_manage_nm': '㈜팜한농 울산공장', 'address': '울산광역시 남구 납도로 156 (매암동)'},
#   {'fact_manage_nm': '㈜풍산 울산사업장', 'address': '울산광역시 울주군 온산읍 산암로 94'},
#   {'fact_manage_nm': '㈜한주', 'address': '울산광역시 남구 사평로 60 (부곡동)'},
#   {'fact_manage_nm': '㈜한화온산공장', 'address': '울산광역시 울주군 온산읍 산남길 32'},
#   {'fact_manage_nm': '고려아연㈜온산제련소', 'address': '울산광역시 울주군 온산읍 이진로 139'},
#   {'fact_manage_nm': '금강공업㈜언양공장', 'address': '울산광역시 울주군 삼남면 반구대로 359'},
#   {'fact_manage_nm': '금풍에너지', 'address': '울산광역시 울주군 삼동면 암리3길 22'},
#   {'fact_manage_nm': '금호석유화학㈜ 울산고무공장', 'address': '울산광역시 남구 상개로 64'},
#   {'fact_manage_nm': '대한유화㈜ 온산공장', 'address': '울산광역시 울주군 온산읍 온산로 134'},
#   {'fact_manage_nm': '대한유화㈜울산공장', 'address': '울산광역시 남구 처용로 260-158 (부곡동)'},
#   {'fact_manage_nm': '대한화섬㈜ 울산공장', 'address': '울산광역시 남구 산업로 304'},
#   {'fact_manage_nm': '덕산갈바텍㈜', 'address': '울산광역시 남구 용연로50번길 9 (용연동)'},
#   {'fact_manage_nm': '덕산산업㈜', 'address': '울산광역시 북구 공단길 48 (연암동)'},
#   {'fact_manage_nm': '동서석유화학㈜', 'address': '울산광역시 남구 사평로 108-70'},
#   {'fact_manage_nm': '디알액시온원산공장', 'address': '울산광역시 울주군 온산읍 산남길 55'},
#   {'fact_manage_nm': '롯데이네오스화학㈜', 'address': '울산광역시 울주군 청량읍 상개로 63-15'},
#   {'fact_manage_nm': '롯데정밀화학㈜울산공장', 'address': '울산광역시 남구 여천로217번길 19'},
#   {'fact_manage_nm': '롯데케미칼㈜ 울산1공장', 'address': '울산광역시 남구 사평로 119'},
#   {'fact_manage_nm': '롯데케미칼㈜울산2공장', 'address': '울산광역시 남구 용연로 184 (용연동)'},
#   {'fact_manage_nm': '무림P&P㈜', 'address': '울산광역시 울주군 온산읍 우봉강양로 3-36'},
#   {'fact_manage_nm': '미원화학㈜', 'address': '울산광역시 남구 장생포로 247 (매암동)'},
#   {'fact_manage_nm': '바스프퍼포먼스폴리아마이드코리아(주)',
#    'address': '울산광역시 울주군 온산읍 공단로 160'},
#   {'fact_manage_nm': '성창보드㈜', 'address': '울산광역시 울주군 삼남면 강당로 35'},
#   {'fact_manage_nm': '송원산업(주)', 'address': '울산광역시 남구 장생포로 83 (여천동)'},
#   {'fact_manage_nm': '송원산업㈜ 매암', 'address': '울산광역시 남구 매암로 14 (매암동)'},
#   {'fact_manage_nm': '애경케미칼(주) 울산공장', 'address': '울산광역시 남구 상개로 81'},
#   {'fact_manage_nm': '어프로티움(주) 울산 제2공장', 'address': '울산광역시 남구 용잠로 169'},
#   {'fact_manage_nm': '어프로티움(주) 울산제3공장', 'address': '울산광역시 울주군 온산읍 회학2길 34'},
#   {'fact_manage_nm': '에스케이멀티유틸리티(주)', 'address': '울산광역시 남구 처용로 718'},
#   {'fact_manage_nm': '에스케이어드밴스드㈜', 'address': '울산광역시 남구 용연로 299 (황성동)'},
#   {'fact_manage_nm': '에스케이에코프라임㈜', 'address': '울산광역시 남구 처용로 718'},
#   {'fact_manage_nm': '에스케이케미칼(주)', 'address': '울산광역시 남구 처용로 718 (황성동)'},
#   {'fact_manage_nm': '에이치디씨현대이피㈜', 'address': '울산광역시 남구 사평로 108-256'},
#   {'fact_manage_nm': '에이치디현대중공업(주)현대소각설비', 'address': '울산광역시 동구 방어진순환도로 140'},
#   {'fact_manage_nm': '엘에스엠앤엠(주)', 'address': '울산광역시 울주군 온산읍 산암로 148'},
#   {'fact_manage_nm': '용산케미칼(주)울산공장', 'address': '울산광역시 남구 사평로 32 (부곡동)'},
#   {'fact_manage_nm': '울산광역시 하수슬러지처리시설', 'address': '울산광역시 남구 처용로 524 (성암동)'},
#   {'fact_manage_nm': '울산광역시생활폐기물소각시설', 'address': '울산광역시 남구 처용로 524 (성암동)'},
#   {'fact_manage_nm': '울산아로마틱스(주)', 'address': '울산광역시 남구 처용로487번길 154'},
#   {'fact_manage_nm': '울산알루미늄', 'address': '울산광역시 남구 부두로 393'},
#   {'fact_manage_nm': '유니드(주) 울산공장', 'address': '울산광역시 남구 상개로 142'},
#   {'fact_manage_nm': '주식회사 다원알로이 울산공장', 'address': '울산광역시 울주군 온산읍 화산1길 30'},
#   {'fact_manage_nm': '지에스에코메탈㈜', 'address': '울산광역시 울주군 온산읍 화산1길 75-34'},
#   {'fact_manage_nm': '케이알에너지㈜', 'address': '울산광역시 남구 장생포고래로29번길 7'},
#   {'fact_manage_nm': '케이지케미칼(주)', 'address': '울산광역시 울주군 온산읍 당월로 322'},
#   {'fact_manage_nm': '코리아피티지(주)', 'address': '울산광역시 남구 용연로179번길 15'},
#   {'fact_manage_nm': '코스모화학(주) 온산공장', 'address': '울산광역시 울주군 온산읍 원봉로 55'},
#   {'fact_manage_nm': '코스포영남파워주식회사', 'address': '울산광역시 남구 장생포로 373'},
#   {'fact_manage_nm': '크나우프석고보드(주)', 'address': '울산광역시 남구 납도로 158 (여천동)'},
#   {'fact_manage_nm': '태광산업(주)석유화학3공장', 'address': '울산광역시 남구 부곡로 68'},
#   {'fact_manage_nm': '태광산업㈜ 석유화학1공장', 'address': '울산광역시 남구 신여천로 154'},
#   {'fact_manage_nm': '태광산업㈜ 석유화학2공장', 'address': '울산광역시 남구 산안로 46'},
#   {'fact_manage_nm': '한국넥슬렌(유)', 'address': '울산광역시 울주군 청량읍 사평로 1'},
#   {'fact_manage_nm': '한국동서발전㈜울산발전본부', 'address': '울산광역시 남구 용잠로 623 (남화동)'},
#   {'fact_manage_nm': '한국바스프㈜울산화성공장', 'address': '울산광역시 남구 신여천로 27'},
#   {'fact_manage_nm': '한국엔지니어링플라스틱㈜', 'address': '울산광역시 남구 장생포고래로 84'},
#   {'fact_manage_nm': '한융금속㈜', 'address': '울산광역시 울주군 온산읍 처용산업1길 11'},
#   {'fact_manage_nm': '한주라이트메탈 주식회사(원산공장)', 'address': '울산광역시 울주군 온산읍 산남길 69'},
#   {'fact_manage_nm': '한화솔루션(주) 울산1공장', 'address': '울산광역시 남구 상개로 141 (상개동)'},
#   {'fact_manage_nm': '한화솔루션㈜ 울산3공장', 'address': '울산광역시 남구 용연로230번길 22'},
#   {'fact_manage_nm': '한화임팩트(주) 울산사업장', 'address': '울산광역시 남구 사평로 71'},
#   {'fact_manage_nm': '현대자동차㈜ 울산공장', 'address': '울산광역시 북구 염포로 700'},
#   {'fact_manage_nm': '효성티앤씨㈜ 울산공장', 'address': '울산광역시 남구 납도로 30'},
#   {'fact_manage_nm': '효성화학㈜ 용연1공장', 'address': '울산광역시 남구 처용로487번길 66'},
#   {'fact_manage_nm': '효성화학㈜ 용연2공장', 'address': '울산광역시 남구 처용로487번길 65'}],
#  '포항시': [{'fact_manage_nm': '(주)삼원강재',
#    'address': '경상북도 포항시 남구 대송면 철강산단로66번길 40'},
#   {'fact_manage_nm': '(주)포스코퓨처엠 포항화학사업부', 'address': '경상북도 포항시 남구 동해안로 6262'},
#   {'fact_manage_nm': '(주)피엔알', 'address': '경상북도 포항시 남구 동해안로 6262'},
#   {'fact_manage_nm': '㈜SIMPAC 포항1공장', 'address': '경상북도 포항시 남구 괴동로 153 (괴동동)'},
#   {'fact_manage_nm': '㈜동림', 'address': '경상북도 포항시 남구 철강로492번길 33'},
#   {'fact_manage_nm': '㈜디케이씨', 'address': '경상북도 포항시 북구 청하면 고현길98번길 66'},
#   {'fact_manage_nm': '㈜레스코', 'address': '경상북도 포항시 남구 동해안로 6262'},
#   {'fact_manage_nm': '㈜렉셈', 'address': '경상북도 포항시 남구 호동로 26'},
#   {'fact_manage_nm': '㈜세기', 'address': '경상북도 포항시 남구 철강산단로 202 (장흥동)'},
#   {'fact_manage_nm': '㈜심팩인더스트리 고순도 FeSi공장',
#    'address': '경상북도 포항시 남구 오천읍 광명산단로 61'},
#   {'fact_manage_nm': '㈜에스피네이처슈레더사업소', 'address': '경상북도 포항시 남구 대송면 철강산단로 176'},
#   {'fact_manage_nm': '㈜유니온 포항공장', 'address': '경상북도 포항시 남구 대송면 송덕로 143'},
#   {'fact_manage_nm': '㈜제철세라믹 포항공장', 'address': '경상북도 포항시 남구 철강로 443'},
#   {'fact_manage_nm': '㈜코스틸포항1공장', 'address': '경상북도 포항시 남구 호동로 35'},
#   {'fact_manage_nm': '㈜포스코', 'address': '경상북도 포항시 남구 동해안로 6261 (괴동동)'},
#   {'fact_manage_nm': '㈜포스코엠텍 제2공장', 'address': '경상북도 포항시 남구 철강로 431'},
#   {'fact_manage_nm': '㈜포스코퓨처엠', 'address': '경상북도 포항시 남구 신항로 110 (청림동)'},
#   {'fact_manage_nm': '㈜한국협화', 'address': '경상북도 포항시 남구 대송로253번길 63 (괴동동)'},
#   {'fact_manage_nm': '㈜화진철강', 'address': '경상북도 포항시 북구 송라면 대전길 97-88'},
#   {'fact_manage_nm': '네이처이앤티㈜', 'address': '경상북도 포항시 남구 대송면 철강로492번길 49'},
#   {'fact_manage_nm': '동국제강㈜ 포항공장', 'address': '경상북도 포항시 남구 대송면 철강산단로 195'},
#   {'fact_manage_nm': '동양산업㈜', 'address': '경상북도 포항시 남구 동해면 동해안로 5327'},
#   {'fact_manage_nm': '동일산업㈜ 봉강사업부', 'address': '경상북도 포항시 남구 대송로 111 (장흥동)'},
#   {'fact_manage_nm': '동일산업㈜ 합금철사업부', 'address': '경상북도 포항시 남구 괴동로 112 (장흥동)'},
#   {'fact_manage_nm': '디케이동신(주)', 'address': '경상북도 포항시 남구 대송로 154'},
#   {'fact_manage_nm': '오씨아이 주식회사 포항공장', 'address': '경상북도 포항시 남구 청림서길 54 (청림동)'},
#   {'fact_manage_nm': '유니온머티리얼㈜포항공장', 'address': '경상북도 포항시 남구 대송로 234'},
#   {'fact_manage_nm': '이비덴그라파이트코리아㈜',
#    'address': '경상북도 포항시 북구 흥해읍 영일만산단남로75번길 41'},
#   {'fact_manage_nm': '포스코스틸리온㈜도금공장', 'address': '경상북도 포항시 남구 철강로 173'},
#   {'fact_manage_nm': '포스코스틸리온㈜컬러공장', 'address': '경상북도 포항시 남구 대송로 243'},
#   {'fact_manage_nm': '포우산업㈜', 'address': '경상북도 포항시 남구 동해안로 6262'},
#   {'fact_manage_nm': '포항이앤이㈜', 'address': '경상북도 포항시 남구 서원재로 82'},
#   {'fact_manage_nm': '한국씨엔티㈜포항지점', 'address': '경상북도 포항시 남구 괴동로 93'},
#   {'fact_manage_nm': '한라시멘트㈜포항', 'address': '경상북도 포항시 남구 대송로101번길 41'},
#   {'fact_manage_nm': '현대제철㈜포항1공장', 'address': '경상북도 포항시 남구 동해안로 6363 (송내동)'},
#   {'fact_manage_nm': '현대제철㈜포항2공장', 'address': '경상북도 포항시 남구 철강로314번길 36 (장흥동)'},
#   {'fact_manage_nm': '현대종합특수강㈜포항1공장', 'address': '경상북도 포항시 남구 대송로 151 (괴동동)'},
#   {'fact_manage_nm': '홍덕산업(주) BW공장', 'address': '경상북도 포항시 남구 철강로 328'}]}

# %%
pip install PyKakao --upgrade
# Out:
# Collecting PyKakao
#   Downloading PyKakao-0.0.7-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from PyKakao) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from PyKakao) (2.31.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from PyKakao) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->PyKakao) (1.16.0)
# Installing collected packages: PyKakao
# Successfully installed PyKakao-0.0.7

# %%
from PyKakao import Local
api = Local(service_key = "28b3114ff644d68e922e5b096abe321e")

# %%
for item in base_data['울산광역시']:
  df =  api.search_address(item['address'], dataframe=True)

  if not df.empty and 'x' in df.columns and 'y' in df.columns:
    x = df['x'][0]
    y = df['y'][0]
    item['x_coord'] = x
    item['y_coord'] = y
  else:
    item['x_coord'] = None
    item['y_coord'] = None

for item in base_data['포항시']:
  df =  api.search_address(item['address'], dataframe=True)

  if not df.empty and 'x' in df.columns and 'y' in df.columns:
    x = df['x'][0]
    y = df['y'][0]
    item['x_coord'] = x
    item['y_coord'] = y
  else:
    item['x_coord'] = None
    item['y_coord'] = None

# %%
with open('base_data.json', "w", encoding='utf-8') as json_file:
    json.dump(base_data, json_file, ensure_ascii=False)
base_data
# Out:
# {'울산광역시': [{'fact_manage_nm': '(주)비아이티',
#    'address': '울산광역시 남구 용잠로 583-93',
#    'x_coord': '129.38383251569',
#    'y_coord': '35.4826435925311'},
#   {'fact_manage_nm': '(주)에너지파크',
#    'address': '울산광역시 남구 처용로 695',
#    'x_coord': '129.354436285338',
#    'y_coord': '35.4690889405951'},
#   {'fact_manage_nm': '(주)에스케이에너지',
#    'address': '울산광역시 남구 신여천로 2 (고사동)',
#    'x_coord': '129.345670845432',
#    'y_coord': '35.5102455092597'},
#   {'fact_manage_nm': '(주)에팩',
#    'address': '울산광역시 남구 장생포로 285 (매암동)',
#    'x_coord': '129.375663913139',
#    'y_coord': '35.5147451744127'},
#   {'fact_manage_nm': 'NC울산㈜',
#    'address': '울산광역시 남구 용잠로 339 (용잠동)',
#    'x_coord': '129.369662839696',
#    'y_coord': '35.4929181593707'},
#   {'fact_manage_nm': 'S-OIL㈜ 온산공장',
#    'address': '울산광역시 울주군 온산읍 온산로 68',
#    'x_coord': '129.340420365021',
#    'y_coord': '35.4388440489497'},
#   {'fact_manage_nm': 'SK picglobal㈜',
#    'address': '울산광역시 남구 용잠로 255',
#    'x_coord': '129.363948181832',
#    'y_coord': '35.4963960353949'},
#   {'fact_manage_nm': 'SK가스㈜',
#    'address': '울산광역시 남구 용잠로 566',
#    'x_coord': '129.375827844777',
#    'y_coord': '35.4746169644977'},
#   {'fact_manage_nm': 'SK엔무브㈜',
#    'address': '울산광역시 남구 신여천로 2',
#    'x_coord': '129.345670845432',
#    'y_coord': '35.5102455092597'},
#   {'fact_manage_nm': 'SK지오센트릭(주)',
#    'address': '울산광역시 남구 신여천로 2',
#    'x_coord': '129.345670845432',
#    'y_coord': '35.5102455092597'},
#   {'fact_manage_nm': '㈜동남 울산공장',
#    'address': '울산광역시 울주군 온산읍 석당길 29',
#    'x_coord': '129.334636595741',
#    'y_coord': '35.4347654705667'},
#   {'fact_manage_nm': '㈜동부에너지',
#    'address': '울산광역시 남구 장생포로 285 (매암동)',
#    'x_coord': '129.375663913139',
#    'y_coord': '35.5147451744127'},
#   {'fact_manage_nm': '㈜범우',
#    'address': '울산광역시 울주군 온산읍 온산로 219-3',
#    'x_coord': '129.333612428326',
#    'y_coord': '35.4580520826551'},
#   {'fact_manage_nm': '㈜삼양사 울산1공장',
#    'address': '울산광역시 남구 장생포로 285',
#    'x_coord': '129.375663913139',
#    'y_coord': '35.5147451744127'},
#   {'fact_manage_nm': '㈜삼양사 울산2공장',
#    'address': '울산광역시 남구 매암로 115',
#    'x_coord': '129.373120777123',
#    'y_coord': '35.5169608499613'},
#   {'fact_manage_nm': '㈜세진메탈',
#    'address': '울산광역시 울주군 온산읍 원봉로 15',
#    'x_coord': '129.338368931568',
#    'y_coord': '35.4190282596538'},
#   {'fact_manage_nm': '㈜세진메탈 3공장',
#    'address': '울산광역시 울주군 온산읍 석당길 29-13',
#    'x_coord': '129.335216430909',
#    'y_coord': '35.4356744260213'},
#   {'fact_manage_nm': '㈜에코비트에너지 울산',
#    'address': '울산광역시 남구 여천로 228 (여천동)',
#    'x_coord': '129.357156952246',
#    'y_coord': '35.5277930374037'},
#   {'fact_manage_nm': '㈜엘엑스하우시스',
#    'address': '울산광역시 울주군 온양읍 덕망로 275',
#    'x_coord': '129.293022051544',
#    'y_coord': '35.4519481993737'},
#   {'fact_manage_nm': '㈜우신금속',
#    'address': '울산광역시 울주군 온산읍 처용산업2길 17',
#    'x_coord': '129.341199668398',
#    'y_coord': '35.465958282809'},
#   {'fact_manage_nm': '㈜유니큰 온산공장',
#    'address': '울산광역시 울주군 온산읍 원산로 59',
#    'x_coord': '129.350454562018',
#    'y_coord': '35.4126056027237'},
#   {'fact_manage_nm': '㈜이수화학 온산공장',
#    'address': '울산광역시 울주군 온산읍 석당길 8',
#    'x_coord': '129.330213003926',
#    'y_coord': '35.4363871132851'},
#   {'fact_manage_nm': '㈜이수화학 울산공장',
#    'address': '울산광역시 남구 사평로 108-224',
#    'x_coord': '129.331989602238',
#    'y_coord': '35.4927980545095'},
#   {'fact_manage_nm': '㈜제이엠씨',
#    'address': '울산광역시 울주군 온산읍 이진로 71',
#    'x_coord': '129.337528385359',
#    'y_coord': '35.4301866569728'},
#   {'fact_manage_nm': '㈜조비',
#    'address': '울산광역시 남구 여천로163번길 22 (여천동)',
#    'x_coord': '129.353290855008',
#    'y_coord': '35.5285345428371'},
#   {'fact_manage_nm': '㈜카프로',
#    'address': '울산광역시 남구 사평로 108-12 (부곡동)',
#    'x_coord': '129.329362870225',
#    'y_coord': '35.4973349507858'},
#   {'fact_manage_nm': '㈜코엔텍',
#    'address': '울산광역시 남구 용잠로 328 (용잠동)',
#    'x_coord': '129.367887389388',
#    'y_coord': '35.487939459466'},
#   {'fact_manage_nm': '㈜토탈',
#    'address': '울산광역시 남구 용연로179번길 18 (용연동)',
#    'x_coord': '129.362261768779',
#    'y_coord': '35.4765983929621'},
#   {'fact_manage_nm': '㈜팜한농 울산공장',
#    'address': '울산광역시 남구 납도로 156 (매암동)',
#    'x_coord': '129.363220889405',
#    'y_coord': '35.5190867230285'},
#   {'fact_manage_nm': '㈜풍산 울산사업장',
#    'address': '울산광역시 울주군 온산읍 산암로 94',
#    'x_coord': '129.338473395132',
#    'y_coord': '35.4371506571978'},
#   {'fact_manage_nm': '㈜한주',
#    'address': '울산광역시 남구 사평로 60 (부곡동)',
#    'x_coord': '129.327187114242',
#    'y_coord': '35.492082387322'},
#   {'fact_manage_nm': '㈜한화온산공장',
#    'address': '울산광역시 울주군 온산읍 산남길 32',
#    'x_coord': '129.33973533412',
#    'y_coord': '35.4140893134199'},
#   {'fact_manage_nm': '고려아연㈜온산제련소',
#    'address': '울산광역시 울주군 온산읍 이진로 139',
#    'x_coord': '129.340292175954',
#    'y_coord': '35.4308115116669'},
#   {'fact_manage_nm': '금강공업㈜언양공장',
#    'address': '울산광역시 울주군 삼남면 반구대로 359',
#    'x_coord': '129.101390379802',
#    'y_coord': '35.5304495192048'},
#   {'fact_manage_nm': '금풍에너지',
#    'address': '울산광역시 울주군 삼동면 암리3길 22',
#    'x_coord': '129.099406078604',
#    'y_coord': '35.5040946923241'},
#   {'fact_manage_nm': '금호석유화학㈜ 울산고무공장',
#    'address': '울산광역시 남구 상개로 64',
#    'x_coord': '129.326254989725',
#    'y_coord': '35.4892695811122'},
#   {'fact_manage_nm': '대한유화㈜ 온산공장',
#    'address': '울산광역시 울주군 온산읍 온산로 134',
#    'x_coord': '129.335054187622',
#    'y_coord': '35.4530250577901'},
#   {'fact_manage_nm': '대한유화㈜울산공장',
#    'address': '울산광역시 남구 처용로 260-158 (부곡동)',
#    'x_coord': '129.333894418142',
#    'y_coord': '35.4920042222353'},
#   {'fact_manage_nm': '대한화섬㈜ 울산공장',
#    'address': '울산광역시 남구 산업로 304',
#    'x_coord': '129.338281114814',
#    'y_coord': '35.5117292838212'},
#   {'fact_manage_nm': '덕산갈바텍㈜',
#    'address': '울산광역시 남구 용연로50번길 9 (용연동)',
#    'x_coord': '129.356589035198',
#    'y_coord': '35.4856001248487'},
#   {'fact_manage_nm': '덕산산업㈜',
#    'address': '울산광역시 북구 공단길 48 (연암동)',
#    'x_coord': '129.365508978107',
#    'y_coord': '35.571988062794'},
#   {'fact_manage_nm': '동서석유화학㈜',
#    'address': '울산광역시 남구 사평로 108-70',
#    'x_coord': '129.33207266139',
#    'y_coord': '35.4975569519435'},
#   {'fact_manage_nm': '디알액시온원산공장',
#    'address': '울산광역시 울주군 온산읍 산남길 55',
#    'x_coord': '129.341295046181',
#    'y_coord': '35.4131276329233'},
#   {'fact_manage_nm': '롯데이네오스화학㈜',
#    'address': '울산광역시 울주군 청량읍 상개로 63-15',
#    'x_coord': '129.316420269813',
#    'y_coord': '35.4907438892293'},
#   {'fact_manage_nm': '롯데정밀화학㈜울산공장',
#    'address': '울산광역시 남구 여천로217번길 19',
#    'x_coord': '129.368615793935',
#    'y_coord': '35.5256880208969'},
#   {'fact_manage_nm': '롯데케미칼㈜ 울산1공장',
#    'address': '울산광역시 남구 사평로 119',
#    'x_coord': '129.322216862352',
#    'y_coord': '35.4993095045586'},
#   {'fact_manage_nm': '롯데케미칼㈜울산2공장',
#    'address': '울산광역시 남구 용연로 184 (용연동)',
#    'x_coord': '129.358538757108',
#    'y_coord': '35.4773263194949'},
#   {'fact_manage_nm': '무림P&P㈜',
#    'address': '울산광역시 울주군 온산읍 우봉강양로 3-36',
#    'x_coord': '129.354874138662',
#    'y_coord': '35.4072552341396'},
#   {'fact_manage_nm': '미원화학㈜',
#    'address': '울산광역시 남구 장생포로 247 (매암동)',
#    'x_coord': '129.369395437108',
#    'y_coord': '35.5123906294092'},
#   {'fact_manage_nm': '바스프퍼포먼스폴리아마이드코리아(주)',
#    'address': '울산광역시 울주군 온산읍 공단로 160',
#    'x_coord': '129.339950741646',
#    'y_coord': '35.4163686365407'},
#   {'fact_manage_nm': '성창보드㈜',
#    'address': '울산광역시 울주군 삼남면 강당로 35',
#    'x_coord': '129.095402268214',
#    'y_coord': '35.5193140497825'},
#   {'fact_manage_nm': '송원산업(주)',
#    'address': '울산광역시 남구 장생포로 83 (여천동)',
#    'x_coord': '129.35211169731',
#    'y_coord': '35.5201321369648'},
#   {'fact_manage_nm': '송원산업㈜ 매암',
#    'address': '울산광역시 남구 매암로 14 (매암동)',
#    'x_coord': '129.379087926766',
#    'y_coord': '35.5098241388874'},
#   {'fact_manage_nm': '애경케미칼(주) 울산공장',
#    'address': '울산광역시 남구 상개로 81',
#    'x_coord': '129.316755585484',
#    'y_coord': '35.4919809223168'},
#   {'fact_manage_nm': '어프로티움(주) 울산 제2공장',
#    'address': '울산광역시 남구 용잠로 169',
#    'x_coord': '129.35477958337',
#    'y_coord': '35.4931542747257'},
#   {'fact_manage_nm': '어프로티움(주) 울산제3공장',
#    'address': '울산광역시 울주군 온산읍 회학2길 34',
#    'x_coord': '129.330585107965',
#    'y_coord': '35.4577106150957'},
#   {'fact_manage_nm': '에스케이멀티유틸리티(주)',
#    'address': '울산광역시 남구 처용로 718',
#    'x_coord': '129.359973402085',
#    'y_coord': '35.4650690517039'},
#   {'fact_manage_nm': '에스케이어드밴스드㈜',
#    'address': '울산광역시 남구 용연로 299 (황성동)',
#    'x_coord': '129.360918536513',
#    'y_coord': '35.4662339234142'},
#   {'fact_manage_nm': '에스케이에코프라임㈜',
#    'address': '울산광역시 남구 처용로 718',
#    'x_coord': '129.359973402085',
#    'y_coord': '35.4650690517039'},
#   {'fact_manage_nm': '에스케이케미칼(주)',
#    'address': '울산광역시 남구 처용로 718 (황성동)',
#    'x_coord': '129.359973402085',
#    'y_coord': '35.4650690517039'},
#   {'fact_manage_nm': '에이치디씨현대이피㈜',
#    'address': '울산광역시 남구 사평로 108-256',
#    'x_coord': '129.331575583929',
#    'y_coord': '35.4908322768182'},
#   {'fact_manage_nm': '에이치디현대중공업(주)현대소각설비',
#    'address': '울산광역시 동구 방어진순환도로 140',
#    'x_coord': '129.402774796632',
#    'y_coord': '35.5109395494647'},
#   {'fact_manage_nm': '엘에스엠앤엠(주)',
#    'address': '울산광역시 울주군 온산읍 산암로 148',
#    'x_coord': '129.34997940227',
#    'y_coord': '35.4361525901847'},
#   {'fact_manage_nm': '용산케미칼(주)울산공장',
#    'address': '울산광역시 남구 사평로 32 (부곡동)',
#    'x_coord': '129.327089245544',
#    'y_coord': '35.4896408551375'},
#   {'fact_manage_nm': '울산광역시 하수슬러지처리시설',
#    'address': '울산광역시 남구 처용로 524 (성암동)',
#    'x_coord': '129.344983664928',
#    'y_coord': '35.479918776457'},
#   {'fact_manage_nm': '울산광역시생활폐기물소각시설',
#    'address': '울산광역시 남구 처용로 524 (성암동)',
#    'x_coord': '129.344983664928',
#    'y_coord': '35.479918776457'},
#   {'fact_manage_nm': '울산아로마틱스(주)',
#    'address': '울산광역시 남구 처용로487번길 154',
#    'x_coord': '129.363442961921',
#    'y_coord': '35.4794909941181'},
#   {'fact_manage_nm': '울산알루미늄',
#    'address': '울산광역시 남구 부두로 393',
#    'x_coord': '129.362546894819',
#    'y_coord': '35.5395336691751'},
#   {'fact_manage_nm': '유니드(주) 울산공장',
#    'address': '울산광역시 남구 상개로 142',
#    'x_coord': '129.320588833581',
#    'y_coord': '35.4947407195892'},
#   {'fact_manage_nm': '주식회사 다원알로이 울산공장',
#    'address': '울산광역시 울주군 온산읍 화산1길 30',
#    'x_coord': '129.330957776426',
#    'y_coord': '35.4237723986467'},
#   {'fact_manage_nm': '지에스에코메탈㈜',
#    'address': '울산광역시 울주군 온산읍 화산1길 75-34',
#    'x_coord': '129.33773816681',
#    'y_coord': '35.4277555576398'},
#   {'fact_manage_nm': '케이알에너지㈜',
#    'address': '울산광역시 남구 장생포고래로29번길 7',
#    'x_coord': '129.368906212675',
#    'y_coord': '35.5100535359154'},
#   {'fact_manage_nm': '케이지케미칼(주)',
#    'address': '울산광역시 울주군 온산읍 당월로 322',
#    'x_coord': '129.355716987006',
#    'y_coord': '35.4340235075881'},
#   {'fact_manage_nm': '코리아피티지(주)',
#    'address': '울산광역시 남구 용연로179번길 15',
#    'x_coord': '129.363647134504',
#    'y_coord': '35.4773337305527'},
#   {'fact_manage_nm': '코스모화학(주) 온산공장',
#    'address': '울산광역시 울주군 온산읍 원봉로 55',
#    'x_coord': '129.346890348596',
#    'y_coord': '35.4202126803075'},
#   {'fact_manage_nm': '코스포영남파워주식회사',
#    'address': '울산광역시 남구 장생포로 373',
#    'x_coord': '129.384402180361',
#    'y_coord': '35.5135035773838'},
#   {'fact_manage_nm': '크나우프석고보드(주)',
#    'address': '울산광역시 남구 납도로 158 (여천동)',
#    'x_coord': '129.358785333058',
#    'y_coord': '35.5232387000777'},
#   {'fact_manage_nm': '태광산업(주)석유화학3공장',
#    'address': '울산광역시 남구 부곡로 68',
#    'x_coord': '129.335472339257',
#    'y_coord': '35.5029799847929'},
#   {'fact_manage_nm': '태광산업㈜ 석유화학1공장',
#    'address': '울산광역시 남구 신여천로 154',
#    'x_coord': '129.357218015166',
#    'y_coord': '35.5201417917938'},
#   {'fact_manage_nm': '태광산업㈜ 석유화학2공장',
#    'address': '울산광역시 남구 산안로 46',
#    'x_coord': '129.351065327473',
#    'y_coord': '35.5201665136706'},
#   {'fact_manage_nm': '한국넥슬렌(유)',
#    'address': '울산광역시 울주군 청량읍 사평로 1',
#    'x_coord': '129.32603538876',
#    'y_coord': '35.4878663507681'},
#   {'fact_manage_nm': '한국동서발전㈜울산발전본부',
#    'address': '울산광역시 남구 용잠로 623 (남화동)',
#    'x_coord': '129.383123357278',
#    'y_coord': '35.4797924311309'},
#   {'fact_manage_nm': '한국바스프㈜울산화성공장',
#    'address': '울산광역시 남구 신여천로 27',
#    'x_coord': '129.343219451031',
#    'y_coord': '35.5175704936153'},
#   {'fact_manage_nm': '한국엔지니어링플라스틱㈜',
#    'address': '울산광역시 남구 장생포고래로 84',
#    'x_coord': '129.364971162293',
#    'y_coord': '35.5080288920162'},
#   {'fact_manage_nm': '한융금속㈜',
#    'address': '울산광역시 울주군 온산읍 처용산업1길 11',
#    'x_coord': '129.338806132708',
#    'y_coord': '35.4628838654669'},
#   {'fact_manage_nm': '한주라이트메탈 주식회사(원산공장)',
#    'address': '울산광역시 울주군 온산읍 산남길 69',
#    'x_coord': '129.343201577535',
#    'y_coord': '35.412961335796'},
#   {'fact_manage_nm': '한화솔루션(주) 울산1공장',
#    'address': '울산광역시 남구 상개로 141 (상개동)',
#    'x_coord': '129.316587390105',
#    'y_coord': '35.4976331269499'},
#   {'fact_manage_nm': '한화솔루션㈜ 울산3공장',
#    'address': '울산광역시 남구 용연로230번길 22',
#    'x_coord': '129.358327975184',
#    'y_coord': '35.472472548535'},
#   {'fact_manage_nm': '한화임팩트(주) 울산사업장',
#    'address': '울산광역시 남구 사평로 71',
#    'x_coord': '129.322123192437',
#    'y_coord': '35.4951418044712'},
#   {'fact_manage_nm': '현대자동차㈜ 울산공장',
#    'address': '울산광역시 북구 염포로 700',
#    'x_coord': '129.385657710717',
#    'y_coord': '35.5369292699964'},
#   {'fact_manage_nm': '효성티앤씨㈜ 울산공장',
#    'address': '울산광역시 남구 납도로 30',
#    'x_coord': '129.358483786891',
#    'y_coord': '35.5123184844859'},
#   {'fact_manage_nm': '효성화학㈜ 용연1공장',
#    'address': '울산광역시 남구 처용로487번길 66',
#    'x_coord': '129.354193779589',
#    'y_coord': '35.4810316671169'},
#   {'fact_manage_nm': '효성화학㈜ 용연2공장',
#    'address': '울산광역시 남구 처용로487번길 65',
#    'x_coord': '129.353262194893',
#    'y_coord': '35.4831336415504'}],
#  '포항시': [{'fact_manage_nm': '(주)삼원강재',
#    'address': '경상북도 포항시 남구 대송면 철강산단로66번길 40',
#    'x_coord': '129.372421430618',
#    'y_coord': '35.9571930327'},
#   {'fact_manage_nm': '(주)포스코퓨처엠 포항화학사업부',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'x_coord': None,
#    'y_coord': None},
#   {'fact_manage_nm': '(주)피엔알',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'x_coord': None,
#    'y_coord': None},
#   {'fact_manage_nm': '㈜SIMPAC 포항1공장',
#    'address': '경상북도 포항시 남구 괴동로 153 (괴동동)',
#    'x_coord': '129.374268582346',
#    'y_coord': '35.993219561807'},
#   {'fact_manage_nm': '㈜동림',
#    'address': '경상북도 포항시 남구 철강로492번길 33',
#    'x_coord': '129.383025126264',
#    'y_coord': '35.9665067210112'},
#   {'fact_manage_nm': '㈜디케이씨',
#    'address': '경상북도 포항시 북구 청하면 고현길98번길 66',
#    'x_coord': '129.325798325091',
#    'y_coord': '36.1683044300989'},
#   {'fact_manage_nm': '㈜레스코',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'x_coord': None,
#    'y_coord': None},
#   {'fact_manage_nm': '㈜렉셈',
#    'address': '경상북도 포항시 남구 호동로 26',
#    'x_coord': '129.382175784828',
#    'y_coord': '35.9798085766425'},
#   {'fact_manage_nm': '㈜세기',
#    'address': '경상북도 포항시 남구 철강산단로 202 (장흥동)',
#    'x_coord': '129.374967398583',
#    'y_coord': '35.9688304751641'},
#   {'fact_manage_nm': '㈜심팩인더스트리 고순도 FeSi공장',
#    'address': '경상북도 포항시 남구 오천읍 광명산단로 61',
#    'x_coord': '129.419372885619',
#    'y_coord': '35.9440160647595'},
#   {'fact_manage_nm': '㈜에스피네이처슈레더사업소',
#    'address': '경상북도 포항시 남구 대송면 철강산단로 176',
#    'x_coord': '129.373792295331',
#    'y_coord': '35.9681822266056'},
#   {'fact_manage_nm': '㈜유니온 포항공장',
#    'address': '경상북도 포항시 남구 대송면 송덕로 143',
#    'x_coord': '129.384244629859',
#    'y_coord': '35.9562668171081'},
#   {'fact_manage_nm': '㈜제철세라믹 포항공장',
#    'address': '경상북도 포항시 남구 철강로 443',
#    'x_coord': '129.385329779593',
#    'y_coord': '35.9751088284687'},
#   {'fact_manage_nm': '㈜코스틸포항1공장',
#    'address': '경상북도 포항시 남구 호동로 35',
#    'x_coord': '129.381607660999',
#    'y_coord': '35.984015247162'},
#   {'fact_manage_nm': '㈜포스코',
#    'address': '경상북도 포항시 남구 동해안로 6261 (괴동동)',
#    'x_coord': '129.382450041981',
#    'y_coord': '35.998765593911'},
#   {'fact_manage_nm': '㈜포스코엠텍 제2공장',
#    'address': '경상북도 포항시 남구 철강로 431',
#    'x_coord': '129.385384742351',
#    'y_coord': '35.9753586619178'},
#   {'fact_manage_nm': '㈜포스코퓨처엠',
#    'address': '경상북도 포항시 남구 신항로 110 (청림동)',
#    'x_coord': '129.416143090877',
#    'y_coord': '36.0015690262965'},
#   {'fact_manage_nm': '㈜한국협화',
#    'address': '경상북도 포항시 남구 대송로253번길 63 (괴동동)',
#    'x_coord': '129.372309784817',
#    'y_coord': '36.0041627853985'},
#   {'fact_manage_nm': '㈜화진철강',
#    'address': '경상북도 포항시 북구 송라면 대전길 97-88',
#    'x_coord': '129.356913762272',
#    'y_coord': '36.249217042358'},
#   {'fact_manage_nm': '네이처이앤티㈜',
#    'address': '경상북도 포항시 남구 대송면 철강로492번길 49',
#    'x_coord': '129.38469702767',
#    'y_coord': '35.9641414447141'},
#   {'fact_manage_nm': '동국제강㈜ 포항공장',
#    'address': '경상북도 포항시 남구 대송면 철강산단로 195',
#    'x_coord': '129.371908975619',
#    'y_coord': '35.9673967870883'},
#   {'fact_manage_nm': '동양산업㈜',
#    'address': '경상북도 포항시 남구 동해면 동해안로 5327',
#    'x_coord': '129.48078736819',
#    'y_coord': '35.9845059072197'},
#   {'fact_manage_nm': '동일산업㈜ 봉강사업부',
#    'address': '경상북도 포항시 남구 대송로 111 (장흥동)',
#    'x_coord': '129.36744022438',
#    'y_coord': '35.9922416745453'},
#   {'fact_manage_nm': '동일산업㈜ 합금철사업부',
#    'address': '경상북도 포항시 남구 괴동로 112 (장흥동)',
#    'x_coord': '129.376789926375',
#    'y_coord': '35.9850831900998'},
#   {'fact_manage_nm': '디케이동신(주)',
#    'address': '경상북도 포항시 남구 대송로 154',
#    'x_coord': '129.371461991669',
#    'y_coord': '35.9938703923107'},
#   {'fact_manage_nm': '오씨아이 주식회사 포항공장',
#    'address': '경상북도 포항시 남구 청림서길 54 (청림동)',
#    'x_coord': '129.411950898155',
#    'y_coord': '35.9998439031409'},
#   {'fact_manage_nm': '유니온머티리얼㈜포항공장',
#    'address': '경상북도 포항시 남구 대송로 234',
#    'x_coord': '129.377195364434',
#    'y_coord': '35.9981726202501'},
#   {'fact_manage_nm': '이비덴그라파이트코리아㈜',
#    'address': '경상북도 포항시 북구 흥해읍 영일만산단남로75번길 41',
#    'x_coord': '129.407453231534',
#    'y_coord': '36.0985786200438'},
#   {'fact_manage_nm': '포스코스틸리온㈜도금공장',
#    'address': '경상북도 포항시 남구 철강로 173',
#    'x_coord': '129.364364893353',
#    'y_coord': '35.9898228167942'},
#   {'fact_manage_nm': '포스코스틸리온㈜컬러공장',
#    'address': '경상북도 포항시 남구 대송로 243',
#    'x_coord': '129.375232138907',
#    'y_coord': '36.0007065590803'},
#   {'fact_manage_nm': '포우산업㈜',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'x_coord': None,
#    'y_coord': None},
#   {'fact_manage_nm': '포항이앤이㈜',
#    'address': '경상북도 포항시 남구 서원재로 82',
#    'x_coord': '129.391834202198',
#    'y_coord': '35.9840587491889'},
#   {'fact_manage_nm': '한국씨엔티㈜포항지점',
#    'address': '경상북도 포항시 남구 괴동로 93',
#    'x_coord': '129.369329252668',
#    'y_coord': '35.9877445259736'},
#   {'fact_manage_nm': '한라시멘트㈜포항',
#    'address': '경상북도 포항시 남구 대송로101번길 41',
#    'x_coord': '129.362590274099',
#    'y_coord': '35.9922162444914'},
#   {'fact_manage_nm': '현대제철㈜포항1공장',
#    'address': '경상북도 포항시 남구 동해안로 6363 (송내동)',
#    'x_coord': '129.374109577448',
#    'y_coord': '36.005693531948'},
#   {'fact_manage_nm': '현대제철㈜포항2공장',
#    'address': '경상북도 포항시 남구 철강로314번길 36 (장흥동)',
#    'x_coord': '129.37029436333',
#    'y_coord': '35.9761502690989'},
#   {'fact_manage_nm': '현대종합특수강㈜포항1공장',
#    'address': '경상북도 포항시 남구 대송로 151 (괴동동)',
#    'x_coord': '129.367338755565',
#    'y_coord': '35.9951890303024'},
#   {'fact_manage_nm': '홍덕산업(주) BW공장',
#    'address': '경상북도 포항시 남구 철강로 328',
#    'x_coord': '129.373811766247',
#    'y_coord': '35.9788815302865'}]}

# %%
# 1. 첫 번째 함수 각 공장별 데이터 합치기 10분단위로 그 전에 먼저, 같은 공장이면 다 더하기
# 1.5. 1.5함수 None 한글로 되어있는거 쳐내기
# 2. 두 번째 함수 시간을 선택하면 그 시간을 기준으로 3시간 선형보간
# 3. 세 번째 함수 선택시 기준으로 풍속 풍향으로 이동 현재 위치의 SOX는 마이너스 이동된 위치에는 플러스
# 4. 세 번째 함수에 들어갈 데이터 형식은 x, y, SOX양, 풍향, 풍속

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
def factCall(area, step):
  url = 'http://apis.data.go.kr/B552584/cleansys/rltmMesureResult'
  params ={'serviceKey' : 'zyPKasfClmXWQUP0jZLMGiyMTO0Ykuzu1p5AXxRMTWZLpzeDtt58hJaPT4VvUMpwsswMa2pMScIgEKCGwb3ECw==', 'areaNm' : area, 'type' : 'json' }


  try:
    response = requests.get(url, params=params)
    data = response.json()
    return data
  except json.JSONDecodeError:
    if step > 3:
      return None
    factCall(area, step + 1)



fact_data1 = factCall('울산', 0) #울산
fact_data2 = factCall('경상북도', 0) #경상북도

# %%
from datetime import datetime

# %%
def first_data(): #초기 한번만 실행
  with open('base_data.json', "r", encoding='utf-8') as json_file:
    base_data = json.load(json_file)
  middle_data ={
      "울산광역시": [],
      "포항시" : []
  }
  for item in base_data['울산광역시']:
    for item2 in fact_data1['response']['body']['items']:
      if item2['sox_mesure_value'] == None:
        continue
      elif is_number(item2['sox_mesure_value']) == False:
        continue

      if item['fact_manage_nm'] == item2['fact_manage_nm']:
        mesure_dt = datetime.strptime(item2['mesure_dt'], '%Y-%m-%d %H:%M')
        time = mesure_dt.strftime('%H:%M')
        new_data = {
            "fact_manage_nm": item['fact_manage_nm'],
            "address" : item['address'],
            "SOX" : item2['sox_mesure_value'],
            "x_coord" : item['x_coord'],
            "y_coord" : item['y_coord'],
            "time" : time,
        }
        middle_data['울산광역시'].append(new_data)
  factories = {}

  for entry in middle_data['울산광역시']:
    name = entry['fact_manage_nm']
    if name not in factories:
        # 공장이 처음 나올 경우, 정보 등록
        factories[name] = entry.copy()  # 현재 entry를 복사하여 저장
        factories[name]['SOX'] = float(entry['SOX'])  # 문자열을 실수로 변환
    else:
        # 이미 등록된 공장인 경우, SOX 값만 누적
        factories[name]['SOX'] += float(entry['SOX'])

  #포항
  for item in base_data['포항시']:
    for item2 in fact_data2['response']['body']['items']:
      if item2['sox_mesure_value'] == None:
        continue
      elif is_number(item2['sox_mesure_value']) == False:
        continue

      if item['fact_manage_nm'] == item2['fact_manage_nm']:
        mesure_dt = datetime.strptime(item2['mesure_dt'], '%Y-%m-%d %H:%M')
        time = mesure_dt.strftime('%H:%M')
        new_data = {
            "fact_manage_nm": item['fact_manage_nm'],
            "address" : item['address'],
            "SOX" : item2['sox_mesure_value'],
            "x_coord" : item['x_coord'],
            "y_coord" : item['y_coord'],
            "time" : time,
        }
        middle_data['포항시'].append(new_data)
  factories2 = {}

  for entry in middle_data['포항시']:
    name = entry['fact_manage_nm']
    if name not in factories2:
        # 공장이 처음 나올 경우, 정보 등록
        factories2[name] = entry.copy()  # 현재 entry를 복사하여 저장
        factories2[name]['SOX'] = float(entry['SOX'])  # 문자열을 실수로 변환
    else:
        # 이미 등록된 공장인 경우, SOX 값만 누적
        factories2[name]['SOX'] += float(entry['SOX'])
  data = {
      '울산광역시': list(factories.values()),
      '포항시' : list(factories2.values())
  }
  with open('middle_data.json', "w", encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False)
  return data

first_data()
# Out:
# {'울산광역시': [{'fact_manage_nm': '(주)에너지파크',
#    'address': '울산광역시 남구 처용로 695',
#    'SOX': 0.34,
#    'x_coord': '129.354436285338',
#    'y_coord': '35.4690889405951',
#    'time': '17:00'},
#   {'fact_manage_nm': '(주)에스케이에너지',
#    'address': '울산광역시 남구 신여천로 2 (고사동)',
#    'SOX': 360.98999999999995,
#    'x_coord': '129.345670845432',
#    'y_coord': '35.5102455092597',
#    'time': '17:00'},
#   {'fact_manage_nm': '(주)에팩',
#    'address': '울산광역시 남구 장생포로 285 (매암동)',
#    'SOX': 1.19,
#    'x_coord': '129.375663913139',
#    'y_coord': '35.5147451744127',
#    'time': '17:00'},
#   {'fact_manage_nm': 'NC울산㈜',
#    'address': '울산광역시 남구 용잠로 339 (용잠동)',
#    'SOX': 4.22,
#    'x_coord': '129.369662839696',
#    'y_coord': '35.4929181593707',
#    'time': '17:00'},
#   {'fact_manage_nm': 'S-OIL㈜ 온산공장',
#    'address': '울산광역시 울주군 온산읍 온산로 68',
#    'SOX': 184.93,
#    'x_coord': '129.340420365021',
#    'y_coord': '35.4388440489497',
#    'time': '17:00'},
#   {'fact_manage_nm': 'SK picglobal㈜',
#    'address': '울산광역시 남구 용잠로 255',
#    'SOX': 0.0,
#    'x_coord': '129.363948181832',
#    'y_coord': '35.4963960353949',
#    'time': '16:30'},
#   {'fact_manage_nm': 'SK지오센트릭(주)',
#    'address': '울산광역시 남구 신여천로 2',
#    'SOX': 70.06,
#    'x_coord': '129.345670845432',
#    'y_coord': '35.5102455092597',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜동남 울산공장',
#    'address': '울산광역시 울주군 온산읍 석당길 29',
#    'SOX': 4.4799999999999995,
#    'x_coord': '129.334636595741',
#    'y_coord': '35.4347654705667',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜삼양사 울산2공장',
#    'address': '울산광역시 남구 매암로 115',
#    'SOX': 0.0,
#    'x_coord': '129.373120777123',
#    'y_coord': '35.5169608499613',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜세진메탈',
#    'address': '울산광역시 울주군 온산읍 원봉로 15',
#    'SOX': 13.770000000000001,
#    'x_coord': '129.338368931568',
#    'y_coord': '35.4190282596538',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜세진메탈 3공장',
#    'address': '울산광역시 울주군 온산읍 석당길 29-13',
#    'SOX': 1.8199999999999998,
#    'x_coord': '129.335216430909',
#    'y_coord': '35.4356744260213',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜에코비트에너지 울산',
#    'address': '울산광역시 남구 여천로 228 (여천동)',
#    'SOX': 0.0,
#    'x_coord': '129.357156952246',
#    'y_coord': '35.5277930374037',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜우신금속',
#    'address': '울산광역시 울주군 온산읍 처용산업2길 17',
#    'SOX': 29.03,
#    'x_coord': '129.341199668398',
#    'y_coord': '35.465958282809',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜유니큰 온산공장',
#    'address': '울산광역시 울주군 온산읍 원산로 59',
#    'SOX': 0.0,
#    'x_coord': '129.350454562018',
#    'y_coord': '35.4126056027237',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜이수화학 온산공장',
#    'address': '울산광역시 울주군 온산읍 석당길 8',
#    'SOX': 0.0,
#    'x_coord': '129.330213003926',
#    'y_coord': '35.4363871132851',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜이수화학 울산공장',
#    'address': '울산광역시 남구 사평로 108-224',
#    'SOX': 2.37,
#    'x_coord': '129.331989602238',
#    'y_coord': '35.4927980545095',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜카프로',
#    'address': '울산광역시 남구 사평로 108-12 (부곡동)',
#    'SOX': 0.3,
#    'x_coord': '129.329362870225',
#    'y_coord': '35.4973349507858',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜코엔텍',
#    'address': '울산광역시 남구 용잠로 328 (용잠동)',
#    'SOX': 0.81,
#    'x_coord': '129.367887389388',
#    'y_coord': '35.487939459466',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜토탈',
#    'address': '울산광역시 남구 용연로179번길 18 (용연동)',
#    'SOX': 7.47,
#    'x_coord': '129.362261768779',
#    'y_coord': '35.4765983929621',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜팜한농 울산공장',
#    'address': '울산광역시 남구 납도로 156 (매암동)',
#    'SOX': 173.49,
#    'x_coord': '129.363220889405',
#    'y_coord': '35.5190867230285',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜한주',
#    'address': '울산광역시 남구 사평로 60 (부곡동)',
#    'SOX': 39.83,
#    'x_coord': '129.327187114242',
#    'y_coord': '35.492082387322',
#    'time': '17:00'},
#   {'fact_manage_nm': '고려아연㈜온산제련소',
#    'address': '울산광역시 울주군 온산읍 이진로 139',
#    'SOX': 374.23999999999995,
#    'x_coord': '129.340292175954',
#    'y_coord': '35.4308115116669',
#    'time': '17:00'},
#   {'fact_manage_nm': '금호석유화학㈜ 울산고무공장',
#    'address': '울산광역시 남구 상개로 64',
#    'SOX': 10.459999999999999,
#    'x_coord': '129.326254989725',
#    'y_coord': '35.4892695811122',
#    'time': '17:00'},
#   {'fact_manage_nm': '대한유화㈜ 온산공장',
#    'address': '울산광역시 울주군 온산읍 온산로 134',
#    'SOX': 1.24,
#    'x_coord': '129.335054187622',
#    'y_coord': '35.4530250577901',
#    'time': '17:00'},
#   {'fact_manage_nm': '롯데이네오스화학㈜',
#    'address': '울산광역시 울주군 청량읍 상개로 63-15',
#    'SOX': 0.0,
#    'x_coord': '129.316420269813',
#    'y_coord': '35.4907438892293',
#    'time': '17:00'},
#   {'fact_manage_nm': '롯데케미칼㈜ 울산1공장',
#    'address': '울산광역시 남구 사평로 119',
#    'SOX': 5.11,
#    'x_coord': '129.322216862352',
#    'y_coord': '35.4993095045586',
#    'time': '17:00'},
#   {'fact_manage_nm': '롯데케미칼㈜울산2공장',
#    'address': '울산광역시 남구 용연로 184 (용연동)',
#    'SOX': 44.55,
#    'x_coord': '129.358538757108',
#    'y_coord': '35.4773263194949',
#    'time': '17:00'},
#   {'fact_manage_nm': '무림P&P㈜',
#    'address': '울산광역시 울주군 온산읍 우봉강양로 3-36',
#    'SOX': 0.61,
#    'x_coord': '129.354874138662',
#    'y_coord': '35.4072552341396',
#    'time': '17:00'},
#   {'fact_manage_nm': '미원화학㈜',
#    'address': '울산광역시 남구 장생포로 247 (매암동)',
#    'SOX': 0.0,
#    'x_coord': '129.369395437108',
#    'y_coord': '35.5123906294092',
#    'time': '17:00'},
#   {'fact_manage_nm': '성창보드㈜',
#    'address': '울산광역시 울주군 삼남면 강당로 35',
#    'SOX': 0.0,
#    'x_coord': '129.095402268214',
#    'y_coord': '35.5193140497825',
#    'time': '17:00'},
#   {'fact_manage_nm': '송원산업(주)',
#    'address': '울산광역시 남구 장생포로 83 (여천동)',
#    'SOX': 0.78,
#    'x_coord': '129.35211169731',
#    'y_coord': '35.5201321369648',
#    'time': '17:00'},
#   {'fact_manage_nm': '송원산업㈜ 매암',
#    'address': '울산광역시 남구 매암로 14 (매암동)',
#    'SOX': 0.0,
#    'x_coord': '129.379087926766',
#    'y_coord': '35.5098241388874',
#    'time': '17:00'},
#   {'fact_manage_nm': '에스케이멀티유틸리티(주)',
#    'address': '울산광역시 남구 처용로 718',
#    'SOX': 15.3,
#    'x_coord': '129.359973402085',
#    'y_coord': '35.4650690517039',
#    'time': '17:00'},
#   {'fact_manage_nm': '엘에스엠앤엠(주)',
#    'address': '울산광역시 울주군 온산읍 산암로 148',
#    'SOX': 18.669999999999998,
#    'x_coord': '129.34997940227',
#    'y_coord': '35.4361525901847',
#    'time': '17:00'},
#   {'fact_manage_nm': '주식회사 다원알로이 울산공장',
#    'address': '울산광역시 울주군 온산읍 화산1길 30',
#    'SOX': 9.91,
#    'x_coord': '129.330957776426',
#    'y_coord': '35.4237723986467',
#    'time': '17:00'},
#   {'fact_manage_nm': '케이알에너지㈜',
#    'address': '울산광역시 남구 장생포고래로29번길 7',
#    'SOX': 2.9499999999999997,
#    'x_coord': '129.368906212675',
#    'y_coord': '35.5100535359154',
#    'time': '17:00'},
#   {'fact_manage_nm': '코스모화학(주) 온산공장',
#    'address': '울산광역시 울주군 온산읍 원봉로 55',
#    'SOX': 33.6,
#    'x_coord': '129.346890348596',
#    'y_coord': '35.4202126803075',
#    'time': '17:00'},
#   {'fact_manage_nm': '한융금속㈜',
#    'address': '울산광역시 울주군 온산읍 처용산업1길 11',
#    'SOX': 35.92999999999999,
#    'x_coord': '129.338806132708',
#    'y_coord': '35.4628838654669',
#    'time': '17:00'}],
#  '포항시': [{'fact_manage_nm': '(주)포스코퓨처엠 포항화학사업부',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'SOX': 0.0,
#    'x_coord': None,
#    'y_coord': None,
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜SIMPAC 포항1공장',
#    'address': '경상북도 포항시 남구 괴동로 153 (괴동동)',
#    'SOX': 1.34,
#    'x_coord': '129.374268582346',
#    'y_coord': '35.993219561807',
#    'time': '16:30'},
#   {'fact_manage_nm': '㈜동림',
#    'address': '경상북도 포항시 남구 철강로492번길 33',
#    'SOX': 0.0,
#    'x_coord': '129.383025126264',
#    'y_coord': '35.9665067210112',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜레스코',
#    'address': '경상북도 포항시 남구 동해안로 6262',
#    'SOX': 0.0,
#    'x_coord': None,
#    'y_coord': None,
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜세기',
#    'address': '경상북도 포항시 남구 철강산단로 202 (장흥동)',
#    'SOX': 0.0,
#    'x_coord': '129.374967398583',
#    'y_coord': '35.9688304751641',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜심팩인더스트리 고순도 FeSi공장',
#    'address': '경상북도 포항시 남구 오천읍 광명산단로 61',
#    'SOX': 0.0,
#    'x_coord': '129.419372885619',
#    'y_coord': '35.9440160647595',
#    'time': '16:30'},
#   {'fact_manage_nm': '㈜제철세라믹 포항공장',
#    'address': '경상북도 포항시 남구 철강로 443',
#    'SOX': 0.36,
#    'x_coord': '129.385329779593',
#    'y_coord': '35.9751088284687',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜포스코',
#    'address': '경상북도 포항시 남구 동해안로 6261 (괴동동)',
#    'SOX': 809.5899999999999,
#    'x_coord': '129.382450041981',
#    'y_coord': '35.998765593911',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜포스코엠텍 제2공장',
#    'address': '경상북도 포항시 남구 철강로 431',
#    'SOX': 0.56,
#    'x_coord': '129.385384742351',
#    'y_coord': '35.9753586619178',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜포스코퓨처엠',
#    'address': '경상북도 포항시 남구 신항로 110 (청림동)',
#    'SOX': 3.04,
#    'x_coord': '129.416143090877',
#    'y_coord': '36.0015690262965',
#    'time': '17:00'},
#   {'fact_manage_nm': '㈜화진철강',
#    'address': '경상북도 포항시 북구 송라면 대전길 97-88',
#    'SOX': 3.42,
#    'x_coord': '129.356913762272',
#    'y_coord': '36.249217042358',
#    'time': '17:00'},
#   {'fact_manage_nm': '네이처이앤티㈜',
#    'address': '경상북도 포항시 남구 대송면 철강로492번길 49',
#    'SOX': 1.03,
#    'x_coord': '129.38469702767',
#    'y_coord': '35.9641414447141',
#    'time': '17:00'},
#   {'fact_manage_nm': '동국제강㈜ 포항공장',
#    'address': '경상북도 포항시 남구 대송면 철강산단로 195',
#    'SOX': 2.68,
#    'x_coord': '129.371908975619',
#    'y_coord': '35.9673967870883',
#    'time': '17:00'},
#   {'fact_manage_nm': '동일산업㈜ 합금철사업부',
#    'address': '경상북도 포항시 남구 괴동로 112 (장흥동)',
#    'SOX': 1.65,
#    'x_coord': '129.376789926375',
#    'y_coord': '35.9850831900998',
#    'time': '17:00'},
#   {'fact_manage_nm': '오씨아이 주식회사 포항공장',
#    'address': '경상북도 포항시 남구 청림서길 54 (청림동)',
#    'SOX': 0.02,
#    'x_coord': '129.411950898155',
#    'y_coord': '35.9998439031409',
#    'time': '17:00'},
#   {'fact_manage_nm': '이비덴그라파이트코리아㈜',
#    'address': '경상북도 포항시 북구 흥해읍 영일만산단남로75번길 41',
#    'SOX': 2.3,
#    'x_coord': '129.407453231534',
#    'y_coord': '36.0985786200438',
#    'time': '16:30'},
#   {'fact_manage_nm': '포항이앤이㈜',
#    'address': '경상북도 포항시 남구 서원재로 82',
#    'SOX': 0.14,
#    'x_coord': '129.391834202198',
#    'y_coord': '35.9840587491889',
#    'time': '17:00'},
#   {'fact_manage_nm': '한라시멘트㈜포항',
#    'address': '경상북도 포항시 남구 대송로101번길 41',
#    'SOX': 0.0,
#    'x_coord': '129.362590274099',
#    'y_coord': '35.9922162444914',
#    'time': '16:30'},
#   {'fact_manage_nm': '현대제철㈜포항1공장',
#    'address': '경상북도 포항시 남구 동해안로 6363 (송내동)',
#    'SOX': 2.7,
#    'x_coord': '129.374109577448',
#    'y_coord': '36.005693531948',
#    'time': '17:00'},
#   {'fact_manage_nm': '현대제철㈜포항2공장',
#    'address': '경상북도 포항시 남구 철강로314번길 36 (장흥동)',
#    'SOX': 0.22,
#    'x_coord': '129.37029436333',
#    'y_coord': '35.9761502690989',
#    'time': '17:00'}]}

# %%
import pandas as pd

def linear(): # 특정시 매개변수 보내면 그 시간 기준으로 이후에 데이터들을 Time에 추가 한 다음 선형보간
  data = {
      'Time': ['10:00', '13:00', '14:30', '16:00'],
      'Sox': [20, 23, 25, 27]
  }

  df = pd.DataFrame(data)
  df['Time'] = pd.to_datetime(df['Time'])
  df.set_index('Time', inplace=True)

  df_interpolated = df.resample('30T').interpolate()

  print(df_interpolated)

linear()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f35368743da9> in <cell line: 17>()
#      15   print(df_interpolated)
#      16
# ---> 17 linear()
#
# TypeError: linear() missing 1 required positional argument: 'finally_data'
